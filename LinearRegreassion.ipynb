# %% [markdown]
# <h3>Task 01:Your objective is to manually compute the slope (M) and y-intercept (C) using Ordinary Least Squares Linear Regression.Once determined, apply these values to predict the price when the vegetable weight is 6.5

# %%
# !pip install pandas
# !pip install sklearn
# !pip install matplotlib
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
# ...

# %%
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel('vegetable.xlsx')
df.head()
# Out:
#    Weight  Price
# 0     2.0   35.0
# 1     4.0   60.0
# 2     5.0   20.0
# 3     3.0   50.0
# 4     6.0   50.0

# %%
df.shape
# Out:
# (8, 2)

# %%
df['Price'] = pd.to_numeric(df['Price'],errors='coerce')
df['Weight'] = pd.to_numeric(df['Weight'],errors='coerce')

# %%
x = df['Weight']
y = df['Price']
mean_x=np.mean(x)
mean_y=np.mean(y)

# %%
df.describe()
# Out:
#          Weight      Price
# count  8.000000   8.000000
# mean   4.812500  47.608750
# std    1.730762  13.653949
# min    2.000000  20.000000
# 25%    3.750000  46.250000
# 50%    5.000000  50.435000
# 75%    6.125000  56.250000
# max    7.000000  60.000000

# %%
mean_x
# Out:
# np.float64(4.8125)

# %%
mean_y
# Out:
# np.float64(47.60875)

# %%
dev_x = x-mean_x
dev_y = y-mean_y
m = np.sum(dev_x*dev_y)/np.sum(dev_x**2)
c=mean_y-m*mean_x

print("m",m)
print("c",c)
# Out:
# m 2.5141281669150524
# c 35.50950819672131

# %%
m*6.5+c
# Out:
# np.float64(51.85134128166915)

# %%
df['Predicted_Price'] = m * df['Weight'] + c

# %%
df.describe()
# Out:
#          Weight      Price  Predicted_Price
# count  8.000000   8.000000         8.000000
# mean   4.812500  47.608750        47.608750
# std    1.730762  13.653949         4.351356
# min    2.000000  20.000000        40.537765
# 25%    3.750000  46.250000        44.937489
# 50%    5.000000  50.435000        48.080149
# 75%    6.125000  56.250000        50.908543
# max    7.000000  60.000000        53.108405

# %% [markdown]
# <h3> Task 02:
#  Compute the residuals for each data point.

# %%
df['Residual'] = df['Price'] - df['Predicted_Price']
df
# Out:
#    Weight  Price  Predicted_Price   Residual
# 0     2.0  35.00        40.537765  -5.537765
# 1     4.0  60.00        45.566021  14.433979
# 2     5.0  20.00        48.080149 -28.080149
# 3     3.0  50.00        43.051893   6.948107
# 4     6.0  50.00        50.594277  -0.594277
# 5     5.0  55.00        48.080149   6.919851
# 6     7.0  60.00        53.108405   6.891595
# 7     6.5  50.87        51.851341  -0.981341

# %%
df.describe()
# Out:
#          Weight      Price  Predicted_Price      Residual
# count  8.000000   8.000000         8.000000  8.000000e+00
# mean   4.812500  47.608750        47.608750 -1.776357e-15
# std    1.730762  13.653949         4.351356  1.294203e+01
# min    2.000000  20.000000        40.537765 -2.808015e+01
# 25%    3.750000  46.250000        44.937489 -2.120447e+00
# 50%    5.000000  50.435000        48.080149  3.148659e+00
# 75%    6.125000  56.250000        50.908543  6.926915e+00
# max    7.000000  60.000000        53.108405  1.443398e+01

# %% [markdown]
# <h3> Task 03:
#  Calculate both the Mean Squared Error (MSE) and Mean Absolute Error (MAE)

# %%
MSE = (df['Residual'] ** 2).mean()

# %%
MSE
# Out:
# np.float64(146.5590205663189)

# %%
MAE = df['Residual'].abs().mean()

# %%
MAE
# Out:
# np.float64(8.798383010432191)

# %% [markdown]
# <h3> Final Task:
#  Generate an Excel file for the given dataset. Utilize Python for all the calculations

# %%
df=pd.DataFrame(df)
df
# Out:
#    Weight  Price  Predicted_Price   Residual
# 0     2.0  35.00        40.537765  -5.537765
# 1     4.0  60.00        45.566021  14.433979
# 2     5.0  20.00        48.080149 -28.080149
# 3     3.0  50.00        43.051893   6.948107
# 4     6.0  50.00        50.594277  -0.594277
# 5     5.0  55.00        48.080149   6.919851
# 6     7.0  60.00        53.108405   6.891595
# 7     6.5  50.87        51.851341  -0.981341
